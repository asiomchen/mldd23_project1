# %%
import pandas as pd
import torch
import numpy as np
from src.utils.finger import encode
from src.utils.modelinit import initialize_model
from scipy.spatial.distance import jaccard, euclidean

# %%
# load validation det for klek
df_klek = pd.read_parquet('data/train_data/big_dataset_std_val_10.parquet').sample(10000)

# load validation set for ECFP
df_ECFP = pd.read_parquet('data/train_data/big_dataset_ECFP_val_10.parquet').sample(10000)

# %%
def unpack(bs):
    bs = str(bs)
    bs = bs.lstrip("b'[").rstrip("']").split(',')
    bs = [int(x) for x in bs]
    return bs

def repack(bs, lg):
    vec = np.zeros(lg)
    vec[bs] = 1
    return vec

# %%
df_klek['fps'] = df_klek['fps'].apply(unpack)
df_ECFP['fps'] = df_ECFP['fps'].apply(unpack)
klek_original = df_klek['fps'].apply(repack, lg=4860)
ECFP_original = df_ECFP['fps'].apply(repack, lg=2048)
klek_original = np.array([x for x in klek_original.to_numpy()])
ECFP_original = np.array([x for x in ECFP_original.to_numpy()])

# %%
# path to klek model weights
klek_path = 'models/GRUv3_klek_sonic/epoch_200.pt'
klek_config_path = 'models/GRUv3_klek_sonic/hyperparameters.ini'

# path to ECFP model weights
ECFP_path = 'models/GRUv3_ECFP_tola/epoch_150.pt'
ECFP_config_path = 'models/GRUv3_ECFP_tola/hyperparameters.ini'

# %%
# initialize models and load weights
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

klek_model = initialize_model(klek_config_path, dropout=False, device=device)
klek_model.load_state_dict(torch.load(klek_path, map_location=device))

ECFP_model = initialize_model(ECFP_config_path, dropout=False, device=device)
ECFP_model.load_state_dict(torch.load(ECFP_path, map_location=device))

print(device)
# Out:
# cuda

# %%
# encode fingerprints
klek_encoded, _ = encode(df_klek, klek_model, device)
ECFP_encoded, _ = encode(df_ECFP, ECFP_model, device)

print(klek_encoded.shape) # (10000, 32)
print(ECFP_encoded.shape) # (10000, 32)
# Out:
# 100%|██████████| 10/10 [00:06<00:00,  1.45it/s]
# 100%|██████████| 10/10 [00:05<00:00,  1.87it/s]
# (10000, 32)
# (10000, 32)

# %%
print(klek_encoded.shape)
print(klek_original.shape)
print(ECFP_encoded.shape)
print(ECFP_original.shape)
# Out:
# (10000, 32)
# (10000, 4860)
# (10000, 32)
# (10000, 2048)

# %%
def draw_pairs(n, max_idx):
    pairs = []
    for _ in range(n):
        idx0 = np.random.randint(0, max_idx)
        idx1 = np.random.randint(0, max_idx)
        while idx0 == idx1:
            idx1 = np.random.randint(0, max_idx)
        pairs.append((idx0, idx1))
    return pairs

def calculate_tanimoto(array, pairs):
    res = []
    for pair in pairs:
        idx0, idx1 = pair
        res.append(jaccard(array[idx0], array[idx1]))
    return res

def calculate_euclidean(array, pairs):
    res = []
    for pair in pairs:
        idx0, idx1 = pair
        res.append(euclidean(array[idx0], array[idx1]))
    return res

# %%
pairs = draw_pairs(10000, 10000)
klek_tan = calculate_tanimoto(klek_original, pairs)
klek_euc = calculate_euclidean(klek_encoded, pairs)
ECFP_tan = calculate_tanimoto(ECFP_original, pairs)
ECFP_euc = calculate_euclidean(ECFP_encoded, pairs)

# %%
print(len(klek_tan))
print(len(klek_euc))
print(len(ECFP_tan))
print(len(ECFP_euc))
# Out:
# 10000
# 10000
# 10000
# 10000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.DataFrame({'Klek_original': klek_tan, 'Klek_encoded': klek_euc, 'ECFP_original': ECFP_tan, 'ECFP_encoded': ECFP_euc})

sns.set(font_scale=2, style='white')
sns.jointplot(data=df, x='Klek_original', y='Klek_encoded', color='steelblue',
              height=8, kind='hist', marginal_kws=dict(bins=20), space=0)
plt.xlabel('K&R FP jaccard distance')
plt.ylabel('Latent euclidean distance')
plt.xlim(0.4, 1)
plt.ylim(3, 13)
plt.savefig("distance_plot_klek.png", format='png', dpi=300)

# %%
sns.set(font_scale=2, style='white')
sns.jointplot(data=df, x='ECFP_original', y='ECFP_encoded', color='cadetblue',
              height=8, kind='hist', marginal_kws=dict(bins=50), space=0)
plt.xlabel('ECFP jaccard distance')
plt.ylabel('Latent euclidean distance')
plt.xlim(0.6, 1)
plt.ylim(3, 13)
plt.savefig("distance_plot_ECFP.png", format='png', dpi=300)

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
X = df['ECFP_original'].to_numpy().reshape(-1, 1)
y = df['ECFP_encoded'].to_numpy().reshape(-1, 1)

X_scaled = MinMaxScaler().fit(X).transform(X)
y_scaled = MinMaxScaler().fit(y).transform(y)

# %%
LR = LinearRegression().fit(X, y)

# %%
print(LR.coef_)
print(LR.intercept_)
# Out:
# [[1.90778667]]
# [-0.69597851]

# %%
from sklearn.metrics import r2_score

# %%
print(r2_score(y, X))
# Out:
# -0.48308726343837827

# %%
df = pd.DataFrame({'Original': X_scaled.reshape(-1), 'Encoded': y_scaled.reshape(-1)})

# %%
df['Original'].hist()
# Out:
# <Axes: >

# %%
df['Encoded'].hist()
# Out:
# <Axes: >

# %%
sns.relplot(df, x='Original', y='Encoded')
plt.show()

# %%
one = np.array([1,0,0,1,1,0,1])
two = np.array([0,1,1,0,0,1,1])
jaccard(one,two)
# Out:
# 0.8571428571428571

# %%
klek_encoded, _ = encode(df_klek, klek_model, device)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  2.38it/s]

# %%
huh = calculate_euclidean(klek_encoded)

# %%
mean_starting = np.mean(huh)

# %%
klek_encoded = klek_encoded[klek_encoded[0, ...] < 0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[143], line 1
# ----> 1 klek_encoded = klek_encoded[klek_encoded[0, ...] < 0]
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 1000 but corresponding boolean dimension is 32

# %%
klek_encoded
# Out:
# (16020,)

# %%
mean_new = np.mean(calculate_euclidean(klek_encoded))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[134], line 1
# ----> 1 mean_new = np.mean(calculate_euclidean(klek_encoded))
#
# Cell In[43], line 12, in calculate_euclidean(array)
#      10 for i in range(array.shape[0]):
#      11     for j in range(i+1, array.shape[0]):
# ---> 12         res.append(euclidean(array[i, :], array[j,:]))
#      13 return res
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed
